# %% [markdown]
# # Compound Image Folder Mapping

# %%
from zebrafish_notebook_utils import build_compound_image_index, build_compound_image_run_map

# %%
compound_image_map_df = build_compound_image_run_map()
compound_image_index_df = build_compound_image_index(compound_image_map_df)

compound_image_map_df.to_csv("compound_image_run_map.csv", index=False)
compound_image_index_df.to_csv("compound_image_index.csv", index=False)

compound_image_map_df.head(20)
# Out:
#                        compound                            compound_class  \
# 0   (RS)-(Tetrazol-5-yl)glycine                        Glutamate agonists
# 1   (RS)-(Tetrazol-5-yl)glycine                        Glutamate agonists
# 2         4-Aminophenyl sulfone  Mixed classes, no known link to seizures
# 3         4-Aminophenyl sulfone  Mixed classes, no known link to seizures
# 4               4-aminopyridine                       K+ channel blockers
# 5               4-aminopyridine                       K+ channel blockers
# 6               4-aminopyridine                       K+ channel blockers
# 7               4-aminopyridine                       K+ channel blockers
# 8                 Aminophylline                Methylxanthine derivatives
# 9                 Aminophylline                Methylxanthine derivatives
# 10                Amitriptyline                 Tricyclic antidepressants
# 11                Amitriptyline                 Tricyclic antidepressants
# 12                Amitriptyline                 Tricyclic antidepressants
# 13                    Amoxapine                 Tricyclic antidepressants
# 14                    Amoxapine                 Tricyclic antidepressants
# 15                  Amphetamine                             Illicit drugs
# 16                  Amphetamine                             Illicit drugs
# 17                  Apomorphine   Mixed classes, unclear link to seizures
# 18                  Apomorphine   Mixed classes, unclear link to seizures
# 19                  Apomorphine   Mixed classes, unclear link to seizures
#
#                                   mechanism_of_action  \
# 0                                    NMDAR_Activation
# 1                                    NMDAR_Activation
# 2                          SulfonamideLike_Antibiotic
# 3                          SulfonamideLike_Antibiotic
# 4                             Kv_Blocker_NonSelective
# 5                             Kv_Blocker_NonSelective
# 6                             Kv_Blocker_NonSelective
# 7                             Kv_Blocker_NonSelective
# 8                         P1_Antagonist_PDE_Inhibitor
# 9                         P1_Antagonist_PDE_Inhibitor
# 10  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...
# 11  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...
# 12  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...
# 13  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...
# 14  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...
# 15                     DAT_NET_SERT_ReuptakeInhibitor
# 16                     DAT_NET_SERT_ReuptakeInhibitor
# 17                             D1_D2R_5HTR_aR_Agonist
# 18                             D1_D2R_5HTR_aR_Agonist
# 19                             D1_D2R_5HTR_aR_Agonist
#
#                                         image_run_dir  \
# 0   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 1   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 2   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 3   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 4   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FIR...
# 5   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FIR...
# 6   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 7   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 8   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 9   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 10  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 11  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 12  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 13  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 14  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 15  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 16  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 17  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 18  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 19  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
#
#                                image_run_dir_relative  \
# 0   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...
# 1   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...
# 2   THIRD BATCH convulsants/4 aminophenyl sulfone ...
# 3   THIRD BATCH convulsants/4 aminophenyl sulfone ...
# 4   FIRST BATCH convulsants/Brain_Imaging_Rerun_-_...
# 5   FIRST BATCH convulsants/Brain_Imaging_Rerun_-_...
# 6   FOURTH BATCH 2018/4-Aminopyridine ReRun 1 28 J...
# 7   FOURTH BATCH 2018/4-Aminopyridine ReRun 2 20 J...
# 8   SECOND BATCH convulsants/Aminophylline 24 nov ...
# 9   SECOND BATCH convulsants/Aminophylline 30 nove...
# 10  FOURTH BATCH 2018/Amitripityline Run 1 12 Feb ...
# 11  FOURTH BATCH 2018/Amitriptyline Run 2 13 Feb 2018
# 12  FOURTH BATCH 2018/Amitriptyline Run1 analysed ...
# 13      FOURTH BATCH 2018/Amoxipine Run 2 23 jan 2018
# 14      FOURTH BATCH 2018/Amoxipine run 1 22 jan 2018
# 15    FOURTH BATCH 2018/Amphetamine Run 1 19 feb 2018
# 16    FOURTH BATCH 2018/Amphetamine Run 2 20 Feb 2018
# 17  THIRD BATCH convulsants/EMETIC COMPOUNDS NOT C...
# 18  THIRD BATCH convulsants/EMETIC COMPOUNDS NOT C...
# 19  THIRD BATCH convulsants/EMETICS RERUN/Apomorph...
#
#                 source_batch  \
# 0          FOURTH BATCH 2018
# 1          FOURTH BATCH 2018
# 2    THIRD BATCH convulsants
# 3    THIRD BATCH convulsants
# 4    FIRST BATCH convulsants
# 5    FIRST BATCH convulsants
# 6          FOURTH BATCH 2018
# 7          FOURTH BATCH 2018
# 8   SECOND BATCH convulsants
# 9   SECOND BATCH convulsants
# 10         FOURTH BATCH 2018
# 11         FOURTH BATCH 2018
# 12         FOURTH BATCH 2018
# 13         FOURTH BATCH 2018
# 14         FOURTH BATCH 2018
# 15         FOURTH BATCH 2018
# 16         FOURTH BATCH 2018
# 17   THIRD BATCH convulsants
# 18   THIRD BATCH convulsants
# 19   THIRD BATCH convulsants
#
#                                              dir_name folder_status
# 0         Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 1         Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 2            4 aminophenyl sulfone run 2 24 july 2017        active
# 3             4 aminophenyl sulfone run1 23 July 2017        active
# 4                                           4AP_0.2OD        active
# 5                                    4AP_Round2_0.2OD        active
# 6                 4-Aminopyridine ReRun 1 28 Jan 2019        active
# 7                 4-Aminopyridine ReRun 2 20 Jan 2019        active
# 8                           Aminophylline 24 nov 2016        active
# 9                          Aminophylline 30 nove 2016        active
# 10                   Amitripityline Run 1 12 Feb 2018        active
# 11                    Amitriptyline Run 2 13 Feb 2018        active
# 12  Amitriptyline Run1 analysed by old script DONT...    do_not_use
# 13                        Amoxipine Run 2 23 jan 2018        active
# 14                        Amoxipine run 1 22 jan 2018        active
# 15                      Amphetamine Run 1 19 feb 2018        active
# 16                      Amphetamine Run 2 20 Feb 2018        active
# 17                      Apomorphine run 1 22 aug 2017        active
# 18                      Apomorphine run 2 23 Aug 2017        active
# 19                 Apomorphine run 1 22 aug 2017 DONE        active

# %%
compound_image_index_df.head(20)
# Out:
#                        compound                            compound_class  \
# 0   (RS)-(Tetrazol-5-yl)glycine                        Glutamate agonists
# 1         4-Aminophenyl sulfone  Mixed classes, no known link to seizures
# 2               4-aminopyridine                       K+ channel blockers
# 3                 Aminophylline                Methylxanthine derivatives
# 4                 Amitriptyline                 Tricyclic antidepressants
# 5                     Amoxapine                 Tricyclic antidepressants
# 6                   Amphetamine                             Illicit drugs
# 7                   Apomorphine   Mixed classes, unclear link to seizures
# 8                      BW373U86                         Opioid analgesics
# 9                     Bemegride                                Analeptics
# 10                  Bethanechol                       Muscarinic agonists
# 11                  Bicuculline                                Analeptics
# 12                    Bupropion                       NDRI Antidepressant
# 13                     Caffeine                Methylxanthine derivatives
# 14                    Carbachol                       Muscarinic agonists
# 15               Chlorpromazine               Phenothiazine antipsychotic
# 16                     Cis-ACPD                        Glutamate agonists
# 17                    Cisplatin  Mixed classes, no known link to seizures
# 18                 Clomipramine                 Tricyclic antidepressants
# 19                    Clonidine  Mixed classes, no known link to seizures
#
#                                   mechanism_of_action  n_image_run_dirs  \
# 0                                    NMDAR_Activation                 2
# 1                          SulfonamideLike_Antibiotic                 2
# 2                             Kv_Blocker_NonSelective                 4
# 3                         P1_Antagonist_PDE_Inhibitor                 2
# 4   NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...                 3
# 5   NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...                 2
# 6                      DAT_NET_SERT_ReuptakeInhibitor                 2
# 7                              D1_D2R_5HTR_aR_Agonist                 4
# 8                                         DOR_Agonist                 2
# 9                                   GABAAR_Antagonist                 2
# 10                         mAChR_Agonist_NonSelective                 2
# 11                                  GABAAR_Antagonist                 2
# 12                          NET_DAT_ReuptakeInhibitor                 2
# 13                        P1_Antagonist_PDE_Inhibitor                 5
# 14                                mAChR_nAChR_Agonist                 2
# 15               D1_D2_D3_D4R_MultiReceptorAntagonist                 2
# 16                                   NMDAR_Activation                 2
# 17                  DNA_CrossLinking_Chemotherapeutic                 3
# 18  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...                 2
# 19                                    a2R_Agonist_CNS                 2
#
#     n_active_image_run_dirs  \
# 0                         2
# 1                         2
# 2                         4
# 3                         2
# 4                         2
# 5                         2
# 6                         2
# 7                         4
# 8                         2
# 9                         2
# 10                        2
# 11                        2
# 12                        2
# 13                        4
# 14                        2
# 15                        2
# 16                        2
# 17                        3
# 18                        2
# 19                        2
#
#                                        image_run_dirs  \
# 0   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 1   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 2   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FIR...
# 3   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 4   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 5   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 6   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 7   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 8   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 9   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 10  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 11  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 12  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 13  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 14  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 15  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 16  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 17  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 18  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 19  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
#
#                                 active_image_run_dirs
# 0   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 1   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 2   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FIR...
# 3   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 4   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 5   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 6   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 7   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 8   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 9   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 10  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 11  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 12  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 13  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 14  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 15  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 16  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 17  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 18  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 19  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
