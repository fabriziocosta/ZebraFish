# %% [markdown]
# # Compound Image Concentration Mapping

# %%
from src.notebook_utils import (
    build_compound_image_condition_index,
    build_compound_image_condition_map,
    build_compound_image_run_map,
)

# %%
compound_image_map_df = build_compound_image_run_map()
compound_image_condition_map_df = build_compound_image_condition_map(compound_image_map_df)
compound_image_condition_index_df = build_compound_image_condition_index(compound_image_condition_map_df)

compound_image_condition_map_df.to_csv("compound_image_condition_map.csv", index=False)
compound_image_condition_index_df.to_csv("compound_image_condition_index.csv", index=False)

compound_image_condition_map_df.head(30)
# Out:
#                        compound      compound_class mechanism_of_action  \
# 0   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 1   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 2   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 3   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 4   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 5   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 6   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 7   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 8   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 9   (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 10  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 11  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 12  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 13  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 14  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 15  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 16  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 17  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 18  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 19  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 20  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 21  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 22  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 23  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 24  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 25  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 26  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 27  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 28  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
# 29  (RS)-(Tetrazol-5-yl)glycine  Glutamate agonists    NMDAR_Activation
#
#                                         image_run_dir  \
# 0   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 1   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 2   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 3   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 4   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 5   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 6   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 7   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 8   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 9   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 10  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 11  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 12  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 13  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 14  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 15  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 16  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 17  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 18  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 19  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 20  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 21  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 22  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 23  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 24  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 25  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 26  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 27  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 28  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 29  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
#
#                                image_run_dir_relative       source_batch  \
# 0   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 1   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 2   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 3   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 4   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 5   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 6   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 7   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 8   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 9   FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 10  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 11  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 12  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 13  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 14  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 15  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 16  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 17  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 18  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 19  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 20  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 21  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 22  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 23  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 24  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 25  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 26  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 27  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 28  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
# 29  FOURTH BATCH 2018/Rs tetrazol Glycine (RsT) Ru...  FOURTH BATCH 2018
#
#                                        dir_name folder_status  \
# 0   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 1   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 2   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 3   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 4   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 5   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 6   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 7   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 8   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 9   Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 10  Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 11  Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 12  Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 13  Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 14  Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 15  Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 16  Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 17  Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 18  Rs tetrazol Glycine (RsT) Run 1 21 aug 2018        active
# 19  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 20  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 21  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 22  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 23  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 24  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 25  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 26  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 27  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 28  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
# 29  Rs tetrazol Glycine (RsT) Run 2 24 Aug 2018        active
#
#     exposure_conditions                                image_condition_dir  \
# 0   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 1   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 2   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 3   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 4   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 5   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 6   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 7   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 8   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 9   62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 10  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 11  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 12  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 13  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 14  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 15  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 16  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 17  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 18  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 19  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 20  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 21  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 22  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 23  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 24  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 25  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 26  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 27  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 28  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 29  62.5, 31.25, 15.6μM  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
#
#                              image_condition_dir_name condition_folder_status  \
# 0                                            Water F1                  active
# 1                                            Water F3                  active
# 2                                            Water F4                  active
# 3                                            water F2                  active
# 4                                     15.625microM F1                  active
# 5          15.625microM F2 bright but heart beat good                  active
# 6                                     15.625microM F5                  active
# 7                                     15.625microM F6                  active
# 8           15.625microM f3 run from zero due to slip                  active
# 9                     31.25 microM F2 heart beat fine                  active
# 10                     31.25microM F1 heart beat fine                  active
# 11          31.25microM F3 bright but heart beat good                  active
# 12  31.25microM F4 bright throughout but heart bea...                  active
# 13                                     31.25microM F5                  active
# 14           62.5microM F1 bright but heart beat good                  active
# 15           62.5microM F2 bright but heart beat good                  active
# 16                                      62.5microM F3                  active
# 17                                      62.5microM F4                  active
# 18                                           DONT USE              do_not_use
# 19                                         Water F2.1                  active
# 20                                         Water F2.2                  active
# 21                                         Water F2.3                  active
# 22                                         Water F2.4                  active
# 23        31.25microM F2.1 bright but heart beat fine                  active
# 24                                   31.25microM F2.2                  active
# 25                                   31.25microM F2.3                  active
# 26                                   31.25microM F2.5                  active
# 27                                    62.5microM F2.1                  active
# 28                                    62.5microM F2.2                  active
# 29                                    62.5microM F2.3                  active
#
#    condition_kind  concentration_value concentration_unit  \
# 0         control                  NaN                NaN
# 1         control                  NaN                NaN
# 2         control                  NaN                NaN
# 3         control                  NaN                NaN
# 4       treatment               15.625                 uM
# 5       treatment               15.625                 uM
# 6       treatment               15.625                 uM
# 7       treatment               15.625                 uM
# 8       treatment               15.625                 uM
# 9       treatment               31.250                 uM
# 10      treatment               31.250                 uM
# 11      treatment               31.250                 uM
# 12      treatment               31.250                 uM
# 13      treatment               31.250                 uM
# 14      treatment               62.500                 uM
# 15      treatment               62.500                 uM
# 16      treatment               62.500                 uM
# 17      treatment               62.500                 uM
# 18        unknown                  NaN                 uM
# 19        control                  NaN                NaN
# 20        control                  NaN                NaN
# 21        control                  NaN                NaN
# 22        control                  NaN                NaN
# 23      treatment               31.250                 uM
# 24      treatment               31.250                 uM
# 25      treatment               31.250                 uM
# 26      treatment               31.250                 uM
# 27      treatment               62.500                 uM
# 28      treatment               62.500                 uM
# 29      treatment               62.500                 uM
#
#     concentration_value_uM concentration_label  concentration_rank_in_run  \
# 0                      NaN             control                        NaN
# 1                      NaN             control                        NaN
# 2                      NaN             control                        NaN
# 3                      NaN             control                        NaN
# 4                   15.625           15.625 uM                        1.0
# 5                   15.625           15.625 uM                        1.0
# 6                   15.625           15.625 uM                        1.0
# 7                   15.625           15.625 uM                        1.0
# 8                   15.625           15.625 uM                        1.0
# 9                   31.250            31.25 uM                        2.0
# 10                  31.250            31.25 uM                        2.0
# 11                  31.250            31.25 uM                        2.0
# 12                  31.250            31.25 uM                        2.0
# 13                  31.250            31.25 uM                        2.0
# 14                  62.500             62.5 uM                        3.0
# 15                  62.500             62.5 uM                        3.0
# 16                  62.500             62.5 uM                        3.0
# 17                  62.500             62.5 uM                        3.0
# 18                     NaN                 NaN                        NaN
# 19                     NaN             control                        NaN
# 20                     NaN             control                        NaN
# 21                     NaN             control                        NaN
# 22                     NaN             control                        NaN
# 23                  31.250            31.25 uM                        1.0
# 24                  31.250            31.25 uM                        1.0
# 25                  31.250            31.25 uM                        1.0
# 26                  31.250            31.25 uM                        1.0
# 27                  62.500             62.5 uM                        2.0
# 28                  62.500             62.5 uM                        2.0
# 29                  62.500             62.5 uM                        2.0
#
#    concentration_band  n_treatment_concentrations_in_run
# 0             control                                  3
# 1             control                                  3
# 2             control                                  3
# 3             control                                  3
# 4                 low                                  3
# 5                 low                                  3
# 6                 low                                  3
# 7                 low                                  3
# 8                 low                                  3
# 9                 mid                                  3
# 10                mid                                  3
# 11                mid                                  3
# 12                mid                                  3
# 13                mid                                  3
# 14               high                                  3
# 15               high                                  3
# 16               high                                  3
# 17               high                                  3
# 18            unknown                                  3
# 19            control                                  2
# 20            control                                  2
# 21            control                                  2
# 22            control                                  2
# 23                low                                  2
# 24                low                                  2
# 25                low                                  2
# 26                low                                  2
# 27               high                                  2
# 28               high                                  2
# 29               high                                  2

# %%
compound_image_condition_index_df.head(30)
# Out:
#                        compound                            compound_class  \
# 0   (RS)-(Tetrazol-5-yl)glycine                        Glutamate agonists
# 1   (RS)-(Tetrazol-5-yl)glycine                        Glutamate agonists
# 2   (RS)-(Tetrazol-5-yl)glycine                        Glutamate agonists
# 3   (RS)-(Tetrazol-5-yl)glycine                        Glutamate agonists
# 4   (RS)-(Tetrazol-5-yl)glycine                        Glutamate agonists
# 5         4-Aminophenyl sulfone  Mixed classes, no known link to seizures
# 6         4-Aminophenyl sulfone  Mixed classes, no known link to seizures
# 7         4-Aminophenyl sulfone  Mixed classes, no known link to seizures
# 8         4-Aminophenyl sulfone  Mixed classes, no known link to seizures
# 9         4-Aminophenyl sulfone  Mixed classes, no known link to seizures
# 10              4-aminopyridine                       K+ channel blockers
# 11              4-aminopyridine                       K+ channel blockers
# 12              4-aminopyridine                       K+ channel blockers
# 13              4-aminopyridine                       K+ channel blockers
# 14              4-aminopyridine                       K+ channel blockers
# 15                Aminophylline                Methylxanthine derivatives
# 16                Aminophylline                Methylxanthine derivatives
# 17                Aminophylline                Methylxanthine derivatives
# 18                Aminophylline                Methylxanthine derivatives
# 19                Aminophylline                Methylxanthine derivatives
# 20                Amitriptyline                 Tricyclic antidepressants
# 21                Amitriptyline                 Tricyclic antidepressants
# 22                Amitriptyline                 Tricyclic antidepressants
# 23                Amitriptyline                 Tricyclic antidepressants
# 24                Amitriptyline                 Tricyclic antidepressants
# 25                    Amoxapine                 Tricyclic antidepressants
# 26                    Amoxapine                 Tricyclic antidepressants
# 27                    Amoxapine                 Tricyclic antidepressants
# 28                    Amoxapine                 Tricyclic antidepressants
# 29                    Amoxapine                 Tricyclic antidepressants
#
#                                   mechanism_of_action concentration_band  \
# 0                                    NMDAR_Activation            control
# 1                                    NMDAR_Activation               high
# 2                                    NMDAR_Activation                low
# 3                                    NMDAR_Activation                mid
# 4                                    NMDAR_Activation            unknown
# 5                          SulfonamideLike_Antibiotic            control
# 6                          SulfonamideLike_Antibiotic               high
# 7                          SulfonamideLike_Antibiotic                low
# 8                          SulfonamideLike_Antibiotic                mid
# 9                          SulfonamideLike_Antibiotic            unknown
# 10                            Kv_Blocker_NonSelective            control
# 11                            Kv_Blocker_NonSelective               high
# 12                            Kv_Blocker_NonSelective                low
# 13                            Kv_Blocker_NonSelective                mid
# 14                            Kv_Blocker_NonSelective            unknown
# 15                        P1_Antagonist_PDE_Inhibitor            control
# 16                        P1_Antagonist_PDE_Inhibitor               high
# 17                        P1_Antagonist_PDE_Inhibitor                low
# 18                        P1_Antagonist_PDE_Inhibitor                mid
# 19                        P1_Antagonist_PDE_Inhibitor            unknown
# 20  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...            control
# 21  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...               high
# 22  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...                low
# 23  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...                mid
# 24  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...            unknown
# 25  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...            control
# 26  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...               high
# 27  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...                low
# 28  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...                mid
# 29  NET_SERT_ReuptakeInhibitor_MultiReceptorAntago...            unknown
#
#     n_condition_dirs  n_active_condition_dirs  \
# 0                  8                        8
# 1                  8                        8
# 2                  9                        9
# 3                  5                        5
# 4                  2                        0
# 5                  9                        9
# 6                  8                        8
# 7                  9                        9
# 8                  8                        8
# 9                  1                        0
# 10                11                       11
# 11                11                       11
# 12                10                       10
# 13                12                       12
# 14                 1                        0
# 15                 8                        8
# 16                 5                        5
# 17                 8                        8
# 18                 8                        8
# 19                 2                        0
# 20                 8                        8
# 21                 9                        8
# 22                 8                        8
# 23                 8                        8
# 24                 1                        0
# 25                 8                        8
# 26                 8                        8
# 27                 9                        9
# 28                 8                        8
# 29                 2                        0
#
#                                        condition_dirs
# 0   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 1   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 2   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 3   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 4   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 5   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 6   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 7   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 8   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 9   /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/THI...
# 10  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FIR...
# 11  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FIR...
# 12  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FIR...
# 13  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FIR...
# 14  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 15  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 16  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 17  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 18  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 19  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/SEC...
# 20  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 21  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 22  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 23  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 24  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 25  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 26  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 27  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 28  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
# 29  /mnt/tyler/Matt Winter/BRAIN IMAGES BACKUP/FOU...
